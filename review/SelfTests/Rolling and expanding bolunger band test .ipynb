# %%
#call data and plot the open (make sure index is set to date time)
# set a rolling average/moving average with pandas
#add a 30  nanf 90 day rolling average  roll to the data 
#start of the data series to the point of  value (take into all data up to a point of interest(rolling point))
#expnding (go over)
# crete a bolunger band (go over)

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("resources/walmart_stock.csv", index_col= "Date", parse_dates=True)

# %%
df
# Out:
#                  Open       High        Low      Close    Volume  Adj Close
# Date
# 2012-01-03  59.970001  61.060001  59.869999  60.330002  12668800  52.619235
# 2012-01-04  60.209999  60.349998  59.470001  59.709999   9593300  52.078475
# 2012-01-05  59.349998  59.619999  58.369999  59.419998  12768200  51.825539
# 2012-01-06  59.419998  59.450001  58.869999  59.000000   8069400  51.459220
# 2012-01-09  59.029999  59.549999  58.919998  59.180000   6679300  51.616215
# 2012-01-10  59.430000  59.709999  58.980000  59.040001   6907300  51.494109
# 2012-01-11  59.060001  59.529999  59.040001  59.400002   6365600  51.808098
# 2012-01-12  59.790001  60.000000  59.400002  59.500000   7236400  51.895316
# 2012-01-13  59.180000  59.610001  59.009998  59.540001   7729300  51.930204
# 2012-01-17  59.869999  60.110001  59.520000  59.849998   8500000  52.200581
# 2012-01-18  59.790001  60.029999  59.650002  60.009998   5911400  52.340131
# ...

# %%
df["Open"].plot(figsize =(16,6))
df.rolling(90).mean()["Close"].plot(figsize = (16,6))

# %%
#ets discuss expanding 
df["Close"].expanding().mean().plot(figsize = (16,6))

# %%
#create a bolunger band 
df['Close: 20day Mean'] = df["Close"].rolling(20).mean()
#Close 20 day moving average 
#upper = 20MA + 2*STD
df["Upper"] = df["Close: 20day Mean"]+ 2 * (df["Close"].rolling(20).std())
#lower = 20MA - 2*SDTD
df["Lower"] = df["Close: 20day Mean"] - 2 * (df["Close"].rolling(20).std())

#CLose 
df[["Close","Upper", "Lower", "Close: 20day Mean"]].tail(50).plot(figsize = (16,6))
