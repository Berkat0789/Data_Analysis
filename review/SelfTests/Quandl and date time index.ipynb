# %%
import quandl as qd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
qd.ApiConfig.api_key = 'zm3rueXtNBPQNz5nWNGk'

# %%
real_estate = qd.get('ZILLOW/C13_MRPST')

# %%
real_estate.plot(figsize = (16,6), marker = "o", color = "r", markerfacecolor = "b")

# %%
apple = qd.get("WIKI/FB")

# %%
apple.loc["2012-1-1":]["Adj. Close"].plot(figsize = (16,6), marker = "o")

# %%
tickers = ["FB","GE","F", "AAPL"]
port = pd.DataFrame()
for t in tickers:
    port[t] = qd.get(f"WIKI/{t}")["Adj. Close"]

# %%
port.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1472 entries, 2012-05-18 to 2018-03-27
# Data columns (total 4 columns):
# FB      1472 non-null float64
# GE      1472 non-null float64
# F       1472 non-null float64
# AAPL    1471 non-null float64
# dtypes: float64(4)
# memory usage: 57.5 KB

# %%
port.plot(figsize = (16,6))

# %%
apple_min = port["AAPL"].min()

# %%
for (index, x) in enumerate(port["AAPL"]):
    if x == apple_min:
        print(port.iloc[index])
# Out:
# FB      25.730000
# GE      18.739001
# F       10.456156
# AAPL    50.928800
# Name: 2013-04-19 00:00:00, dtype: float64

# %%
#CREATE A DATE TIME SERIES 
DATE_TIME = datetime(2015,2,12)

# %%
DATE_TIME
# Out:
# datetime.datetime(2015, 2, 12, 0, 0)

# %%
DATE_TIME.day
# Out:
# 12

# %%
DATE_TIME.month
# Out:
# 2

# %%
#creat ea list of date time objects 

first_two = [datetime(2012,1,1), datetime(2012,3,3)]

# %%
first_two
# Out:
# [datetime.datetime(2012, 1, 1, 0, 0), datetime.datetime(2012, 3, 3, 0, 0)]

# %%
dt_index = pd.DatetimeIndex(first_two)

# %%
dt_index
# Out:
# DatetimeIndex(['2012-01-01', '2012-03-03'], dtype='datetime64[ns]', freq=None)

# %%
df = pd.DataFrame(np.random.randn(2,2), index= dt_index, columns=["A", "B"])

# %%
df.index.names = ["Dates"]

# %%
df
# Out:
#                    A         B
# Dates
# 2012-01-01  0.726631 -0.819428
# 2012-03-03  2.331665 -1.715254
