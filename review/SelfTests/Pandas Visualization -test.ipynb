# %%
#import a csv and set the indec (index_col) to a column
#get a histagram for all the data in the first column of a data set
#import seaborn to edet the look of the plots
#create a histogram of a df column 3 different ways (kind, plot,hist, df.hist)
#go through all of the plot types on a df (area, bar, hist, line, scatter, box, hexbin, kde)
#lot using areaa and change the aplha value
#plot using bar and (stacked  = Bool)
#plot using line an (add x) index )  and y)
#scatter plot -> use colot abd size (c = "column", cmap = "coolwarm")
#scatter size map using (s= df["Columns"] * 100 - to make clear . the difference)
#create a box plot for the df
#create a hexagolanl bin using pandas and numpy with 2 columns (increase the gridsize =)
#create kernal density extimation plots (plot.kde())

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv("resources/df1", index_col = 0)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2000-01-01 to 2002-09-26
# Data columns (total 4 columns):
# A    1000 non-null float64
# B    1000 non-null float64
# C    1000 non-null float64
# D    1000 non-null float64
# dtypes: float64(4)
# memory usage: 39.1+ KB

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1["A"].plot.hist(bins = 20, figsize = (16,6))

# %%
df1["A"].hist(figsize = (16,6))

# %%
df1["A"].plot(kind = "hist", figsize = (16,6))

# %%
df2 = pd.read_csv("resources/df2")

# %%
df2.plot.area(figsize =(16,6), alpha = 0.5)

# %%
df2.plot.bar(stacked = True, figsize = (16,6) )

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2["a"].plot.line(figsize = (16,6))

# %%
df2.plot.scatter(x = "a", y = "b", figsize = (16,6), c = "c", s = 50, cmap = "coolwarm")

# %%
df2.plot.box(figsize = (16,6))

# %%
df = pd.DataFrame(np.random.randn(100,2), columns= ["a", "b"])

# %%
df.plot.hexbin(x = "a", y = "b", gridsize = 20)
