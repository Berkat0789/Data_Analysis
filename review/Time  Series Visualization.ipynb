# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import dates
# %matplotlib notebook

# %%
mcdon = pd.read_csv("mcdonalds.csv", index_col = "Date", parse_dates = True)

# %%
mcdon.head()
# Out:
#             Adj. Close  Adj. Volume
# Date
# 1970-01-02    0.209761    2825604.0
# 1970-01-05    0.213316    2210449.5
# 1970-01-06    0.214501    1951168.5
# 1970-01-07    0.213316    2728768.5
# 1970-01-08    0.213316    2242404.0

# %%
mcdon.plot()
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %%
#lets peperate this out

# %%
mcdon["Adj. Close"].plot(figsize =(16,7), xlim = ("1990-1-1", "2010-1-1"), ylim = (0,60))

# %%
mcdon["Adj. Volume"].plot(figsize = (16,7))

# %%
#seperate out the data for a certain range for both the index as well as the  stock data 
idx = mcdon.loc["2001-1-1": "2002-1-1"].index

# %%
idx
# Out:
# DatetimeIndex(['2001-01-02', '2001-01-03', '2001-01-04', '2001-01-05',
#                '2001-01-08', '2001-01-09', '2001-01-10', '2001-01-11',
#                '2001-01-12', '2001-01-16',
#                ...
#                '2001-12-17', '2001-12-18', '2001-12-19', '2001-12-20',
#                '2001-12-21', '2001-12-24', '2001-12-26', '2001-12-27',
#                '2001-12-28', '2001-12-31'],
#               dtype='datetime64[ns]', name='Date', length=248, freq=None)

# %%
stock = mcdon.loc["2001-1-1": "2002-1-1"]["Adj. Close"]

# %%
stock
# Out:
# Date
# 2001-01-02    21.903243
# 2001-01-03    22.027471
# 2001-01-04    21.576329
# 2001-01-05    21.537100
# 2001-01-08    21.576329
# 2001-01-09    21.615559
# 2001-01-10    21.700557
# 2001-01-11    21.373643
# 2001-01-12    21.988241
# 2001-01-16    22.315155
# 2001-01-17    22.681299
# 2001-01-18    21.988241
# 2001-01-19    21.452102
# 2001-01-22    21.903243
# 2001-01-23    21.497870
# 2001-01-24    20.144446
# 2001-01-25    19.327160
# 2001-01-26    18.961017
# 2001-01-29    19.301007
# 2001-01-30    19.255239
# 2001-01-31    19.189857
# 2001-02-01    18.980632
# 2001-02-02    19.242163
# 2001-02-05    19.196395
# 2001-02-06    19.634460
# 2001-02-07    19.137550
# 2001-02-08    19.183318
# 2001-02-09    19.457926
# 2001-02-12    19.503694
# 2001-02-13    19.614845
#                 ...
# 2001-11-16    18.463785
# 2001-11-19    18.364907
# 2001-11-20    17.943028
# 2001-11-21    17.916661
# 2001-11-23    18.140784
# 2001-11-26    18.061682
# 2001-11-27    17.811191
# 2001-11-28    17.639803
# 2001-11-29    17.659578
# 2001-11-30    17.692538
# 2001-12-03    17.613435
# 2001-12-04    17.712313
# 2001-12-05    18.114416
# 2001-12-06    18.206702
# 2001-12-07    17.732089
# 2001-12-10    17.811191
# 2001-12-11    17.468415
# 2001-12-12    16.901515
# 2001-12-13    16.901515
# 2001-12-14    17.666170
# 2001-12-17    17.178373
# 2001-12-18    17.402496
# 2001-12-19    17.250883
# 2001-12-20    16.908107
# 2001-12-21    17.072903
# 2001-12-24    17.039944
# 2001-12-26    17.204740
# 2001-12-27    17.620027
# 2001-12-28    17.534333
# 2001-12-31    17.448639
# Name: Adj. Close, Length: 248, dtype: float64

# %%
#wew ill plot this using subpolts
fig, axe = plt.subplots(figsize = (19,5))
axe.plot_date(idx,stock, "-")
axe.xaxis.set_major_locator(dates.MonthLocator())
axe.xaxis.set_major_formatter(dates.DateFormatter("%b-%y"))
fig.autofmt_xdate()
# Out:
# <img src="data:image/png;base64,..." width="1900">
