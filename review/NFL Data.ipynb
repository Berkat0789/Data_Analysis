# %%
import pandas as pd
import numpy as np 
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/Users/admin/Desktop/python/projects/personal/review'

# %%
combine_data = pd.read_csv("/Users/admin/Desktop/python/projects/personal/Data_Analysis/combine.csv", error_bad_lines=False)
# Out:
# b'Skipping line 97: expected 26 fields, saw 28\nSkipping line 111: expected 26 fields, saw 28\n'

# %%
combine_data
# Out:
#       year            name firstname   lastname position  heightfeet  \
# 0     2015  Ameer Abdullah     Ameer   Abdullah       RB           5
# 1     2015  Nelson Agholor    Nelson    Agholor       WR           6
# 2     2015       Jay Ajayi       Jay      Ajayi       RB           6
# 3     2015  Kwon Alexander      Kwon  Alexander      OLB           6
# 4     2015    Mario Alford     Mario     Alford       WR           5
# ...    ...             ...       ...        ...      ...         ...
# 4940  1999    Daren Yancey     Daren     Yancey       DT           6
# 4941  1999     Craig Yeast     Craig      Yeast       WR           5
# 4942  1999      Ryan Young      Ryan      Young       OT           6
# 4943  1999   Peppi Zellner     Peppi    Zellner       DE           6
# 4944  1999    Amos Zereoue      Amos    Zereoue       RB           5
#
#       heightinches  heightinchestotal  weight  arms  ...  vertical  broad  \
# ...

# %%
index = combine_data["name"]

# %%
combine_data.index = index

# %%
combine_data
# Out:
#                 year            name firstname   lastname position  \
# name
# Ameer Abdullah  2015  Ameer Abdullah     Ameer   Abdullah       RB
# Nelson Agholor  2015  Nelson Agholor    Nelson    Agholor       WR
# Jay Ajayi       2015       Jay Ajayi       Jay      Ajayi       RB
# Kwon Alexander  2015  Kwon Alexander      Kwon  Alexander      OLB
# Mario Alford    2015    Mario Alford     Mario     Alford       WR
# ...              ...             ...       ...        ...      ...
# Daren Yancey    1999    Daren Yancey     Daren     Yancey       DT
# Craig Yeast     1999     Craig Yeast     Craig      Yeast       WR
# Ryan Young      1999      Ryan Young      Ryan      Young       OT
# Peppi Zellner   1999   Peppi Zellner     Peppi    Zellner       DE
# Amos Zereoue    1999    Amos Zereoue      Amos    Zereoue       RB
#
#                 heightfeet  heightinches  heightinchestotal  weight  arms  \
# name
# ...

# %%
combine_data[(combine_data["bench"] > 50) & (combine_data["position"] == "DT")]
# Out:
#                year           name firstname lastname position  heightfeet  \
# name
# Justin Ernest  1999  Justin Ernest    Justin   Ernest       DT           6
#
#                heightinches  heightinchestotal  weight  arms  ...  vertical  \
# name                                                          ...
# Justin Ernest           3.0               75.0     281   0.0  ...      31.0
#
#                broad  bench  round  college  pick  pickround  picktotal  \
# name
# Justin Ernest    113     51      0      NaN   NaN          0          0
#
#                wonderlic  nflgrade
# name
# Justin Ernest          0       0.0
#
# [1 rows x 26 columns]

# %%
#The Highest bench for at DT between 1999 to 2015

# %%
pbp_data = pd.read_csv("/Users/admin/Desktop/python/projects/personal/Data_Analysis/pbp-2019.csv")
pbp_data
# Out:
#            GameId    GameDate  Quarter  Minute  Second OffenseTeam  \
# 0      2019102005  2019-10-20        2       4       5         IND
# 1      2019102005  2019-10-20        2       3      35         IND
# 2      2019102005  2019-10-20        2       2      54         IND
# 3      2019102005  2019-10-20        2       2      11         IND
# 4      2019102005  2019-10-20        2       2       0         IND
# ...           ...         ...      ...     ...     ...         ...
# 37046  2019090800  2019-09-08        1       0       0         NaN
# 37047  2019090801  2019-09-08        2       0       0         NaN
# 37048  2019090800  2019-09-08        3       0       0         NaN
# 37049  2019090500  2019-09-05        2      13       8          GB
# 37050  2019090500  2019-09-05        3      15       0          GB
#
#       DefenseTeam  Down  ToGo  YardLine  ...  IsTwoPointConversion  \
# 0             HOU     3     2        56  ...                     0
# ...

# %%
pbp_data[pbp_data["OffenseTeam"] == "BAL"]
# Out:
#            GameId    GameDate  Quarter  Minute  Second OffenseTeam  \
# 5      2019111001  2019-11-10        3       6      41         BAL
# 6      2019111001  2019-11-10        3       6       9         BAL
# 786    2019120801  2019-12-08        4       9      49         BAL
# 787    2019120801  2019-12-08        4       9      54         BAL
# 788    2019120801  2019-12-08        4      10      33         BAL
# ...           ...         ...      ...     ...     ...         ...
# 36640  2019111001  2019-11-10        3       6       4         BAL
# 36897  2019101301  2019-10-13        2      14      48         BAL
# 36930  2019100607  2019-10-06        1       7      24         BAL
# 36969  2019092901  2019-09-29        1      12      54         BAL
# 37044  2019090803  2019-09-08        3       7      54         BAL
#
#       DefenseTeam  Down  ToGo  YardLine  ...  IsTwoPointConversion  \
# 5             CIN     1    10        67  ...                     0
# ...
