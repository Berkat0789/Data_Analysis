# %%
class Vehicle():
    
    #class onject atributes
       # Will be the same foe any instance of a class
    def __init__(self, doors, color, engine):
        self.doors = doors
        self.color = color
        self.engine = engine
    def checkEngine(self):
        return f"The engine is a {self.engine}"

# %%
bmw = Vehicle(4,"Brown", engine= "V8")

# %%
bmw.color
# Out:
# 'Brown'

# %%
bmw.engine
# Out:
# 'V8'

# %%
bmw.checkEngine()
# Out:
# 'The engine is a V8'

# %% [markdown]
# # we will try making a class that calaulates the retuns for a portfolio

# %%
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
class InvestmentFund():
    def __init__(self, tickers):
        self.tickers = tickers
        
    ##func to get adj Close
    def getAdjClose(self):
        fr = pd.DataFrame()
        for t in self.tickers:
            fr[t] = wb.DataReader(t, "yahoo", start = "2001-1-1")["Adj Close"]
        return fr
    def plotAdjClose(self):
        fr = pd.DataFrame()
        for t in self.tickers:
            fr[t] = wb.DataReader(t, "yahoo", start = "2001-1-1")["Adj Close"]
        return fr.plot(figsize = (16,6))
    def getDailyChanges(self):
        changes_frame = pd.DataFrame()
        daily_changes = pd.DataFrame()
        for t in self.tickers:
            changes_frame[t] = wb.DataReader(t, "yahoo", start = "2001-1-1")["Adj Close"]
            daily_changes[t] = changes_frame[t].pct_change()
        return daily_changes
    def plotDailyChanges(self):
        changes_frame = pd.DataFrame()
        daily_changes = pd.DataFrame()
        for t in self.tickers:
            changes_frame[t] = wb.DataReader(t, "yahoo", start = "2001-1-1")["Adj Close"]
            daily_changes[t] = changes_frame[t].pct_change()
        return [daily_changes.plot(figsize = (16,6)), daily_changes.plot(kind = "box", figsize = (16,6))]

# %%
sidus = InvestmentFund(["F","AMZN", "GE"])

# %%
sidus.getAdjClose()
# Out:
#                     F         AMZN         GE
# Date
# 2001-01-02  14.055985    13.875000  22.765228
# 2001-01-03  14.525725    17.562500  24.879139
# 2001-01-04  15.573597    15.500000  25.009228
# 2001-01-05  15.176129    14.562500  24.618965
# 2001-01-08  14.814793    14.937500  23.708351
# ...               ...          ...        ...
# 2020-01-07   9.250000  1906.859985  12.050000
# 2020-01-08   9.250000  1891.969971  11.940000
# 2020-01-09   9.260000  1901.050049  11.910000
# 2020-01-10   9.250000  1883.160034  11.670000
# 2020-01-13   9.215000  1895.400024  12.050000
#
# [4787 rows x 3 columns]

# %%
sidus.plotAdjClose();

# %%
sidus.getDailyChanges()
# Out:
#                    F      AMZN        GE
# Date
# 2001-01-02       NaN       NaN       NaN
# 2001-01-03  0.033419  0.265766  0.092857
# 2001-01-04  0.072139 -0.117438  0.005229
# 2001-01-05 -0.025522 -0.060484 -0.015605
# 2001-01-08 -0.023810  0.025751 -0.036988
# ...              ...       ...       ...
# 2020-01-07  0.009825  0.002092 -0.007414
# 2020-01-08  0.000000 -0.007809 -0.009129
# 2020-01-09  0.001081  0.004799 -0.002513
# 2020-01-10 -0.001080 -0.009411 -0.020151
# 2020-01-13 -0.004324  0.006500  0.032562
#
# [4787 rows x 3 columns]

# %%
sidus.plotDailyChanges();
