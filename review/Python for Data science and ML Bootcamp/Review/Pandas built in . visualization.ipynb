# %%
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df1 = pd.read_csv("resources/df1", index_col = "Unnamed: 0", parse_dates = True)
df2 = pd.read_csv("resources/df2")

# %%
df1["A"].plot(figsize = (16,6))

# %%
df1["A"].hist(bins = 30, figsize = (16,6))

# %% [markdown]
# # Plotting off the data frame

# %%
df1["A"].plot(kind = "hist")

# %% [markdown]
# ### Call directly on plot call

# %%
df1["A"].plot.hist()

# %% [markdown]
# ## Area Plot

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.area(figsize = (16,6), alpha = 0.5)

# %% [markdown]
# ### BAR Plot -> use when the index is categorical

# %%
df2.plot.bar(figsize = (16,6))

# %% [markdown]
# # Line plot

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.plot.line(y =  "B", figsize = (16,6));

# %%
df1.head(2)
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382

# %%
df1.plot.scatter(x = "A", y = "B", c = 'C', cmap = "coolwarm")

# %% [markdown]
# ### Box plots

# %%
df2.plot.box(figsize = (16,8), cmap = "coolwarm")
