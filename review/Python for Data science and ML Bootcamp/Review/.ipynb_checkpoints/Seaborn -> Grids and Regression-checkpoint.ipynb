# %%
import seaborn as sns 
import matplotlib.pyplot as plt
iris = sns.load_dataset("iris")
# %matplotlib inline

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris)

# %% [markdown]
# ## PairGrid -> same as pair plot but cab be customized with other plot types

# %%
g = sns.PairGrid(iris)
g.map(plt.scatter)
# scatter on the upper middle and lower

# %% [markdown]
# ## what is you want to specify whats on the upper middle and lower

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.scatter)
g.map_upper(plt.kde)
g.map_lower(plt.box)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-f0f6a10d5bc3> in <module>
#       1 g = sns.PairGrid(iris)
# ----> 2 g.map_diag(sns.scatter)
#       3 g.map_upper(plt.kde)
#       4 g.map_lower(plt.box)
#
# AttributeError: module 'seaborn' has no attribute 'scatter'
