# %%
import quandl as qd
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = qd.get("ZILLOW/S32_MRPST", start = "2011-1-1")

# %%
data.plot(figsize = (16,6))

# %%
data.max()
# Out:
# Value    2000.0
# dtype: float64

# %%
stockData = qd.get("WIKI/FB", start = "2011-1-1")

# %%
stockData["Adj. Close"].loc["2018-1-1":].plot()

# %%
movies = pd.read_csv("blockbusters.csv")

# %%
movies["studio"]
# Out:
# 0               Walt Disney Pictures
# 1               Walt Disney Pictures
# 2                              Pixar
# 3                 Universal Pictures
# 4                   20th Century Fox
# 5                 Paramount Pictures
# 6               Walt Disney Pictures
# 7               Walt Disney Pictures
# 8                  Columbia Pictures
# 9                        Warner Bros
# 10              Walt Disney Pictures
# 11              Walt Disney Pictures
# 12                       Warner Bros
# 13                     Sony Pictures
# 14              Walt Disney Pictures
# 15                     Sony Pictures
# 16                       Warner Bros
# 17              Walt Disney Pictures
# 18                Universal Pictures
# 19                       Warner Bros
# 20              Walt Disney Pictures
# 21              Walt Disney Pictures
# 22              Walt Disney Pictures
# 23                Universal Pictures
# 24              Walt Disney Pictures
# ...
