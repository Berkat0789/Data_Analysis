# %% [markdown]
# ### The python jupyter notebook is to compare securties behavor and generate correlation analysis between them. the list of methods to do this is as follows

# %%
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sidusPkg import fetch_Stock_Data

# %%
Sidus = fetch_Stock_Data.Firm(["FB", "AMZN"], start= '2014-1-1')

# %%
Sidus.fetch_Data()
# Out:
# [                   FB        AMZN
#  Date
#  2014-01-02  54.709999  397.970001
#  2014-01-03  54.560001  396.440002
#  2014-01-06  57.200001  393.630005
#  2014-01-07  57.919998  398.029999
#  2014-01-08  58.230000  401.920013,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1c195ce450>]

# %%
Sidus.plot_graphs()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-5e14b167813f> in <module>
# ----> 1 Sidus.plot_graphs()
#
# ~/Desktop/Python/jupyter/Personal Projects/Sidus/sidusPkg/fetch_Stock_Data.py in plot_graphs(self)
#      51                 for index, securt in enumerate(self.data_frame):
#      52                         axes[index].plot(self.data_frame[securt])
# ---> 53                         axes[index].set_xlabel(f"{self.tickers[securt]}")
#      54                         print(f"here is the length {len(self.tickers)}")
#      55                 return fig
#
# TypeError: list indices must be integers or slices, not str

# %%
Sidus.fetch_Data()

# %%
Sidus.dailyChanges("box")

# %%
Sidus.dailyReturns()

# %%
Sidus.compare2("AAPL","TSLA")
