# %% [markdown]
# ### The python jupyter notebook is to compare securties behavor and generate correlation analysis between them. the list of methods to do this is as follows

# %%
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sidusPkg import fetch_Stock_Data

# %%
Sidus = fetch_Stock_Data.Firm(["FB", "AMZN", "TSLA", "AAPL"], start= '2014-1-1')

# %%
Sidus.fetch_Data()
# Out:
# [                   FB        AMZN
#  Date
#  2014-01-02  54.709999  397.970001
#  2014-01-03  54.560001  396.440002
#  2014-01-06  57.200001  393.630005
#  2014-01-07  57.919998  398.029999
#  2014-01-08  58.230000  401.920013,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1c229a0da0>]

# %%
Sidus.dailyChanges("box")
# Out:
# [                  FB      AMZN
#  Date
#  2019-12-24 -0.005141 -0.002114
#  2019-12-26  0.013017  0.044467
#  2019-12-27  0.001492  0.000551
#  2019-12-30 -0.017732 -0.012253
#  2019-12-31  0.004109  0.000514,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1c22d186d8>]

# %%
Sidus.dailyReturns()
# Out:
# [                  FB      AMZN
#  Date
#  2019-12-24  3.749223  4.495841
#  2019-12-26  3.798026  4.695756
#  2019-12-27  3.803692  4.698344
#  2019-12-30  3.736246  4.640777
#  2019-12-31  3.751599  4.643164,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1c22c73128>]

# %%
Sidus.compare("FB","AMZN")
# Out:
# (<class 'statsmodels.iolib.summary2.Summary'>
#  """
#                    Results: Ordinary least squares
#  ===================================================================
#  Model:              OLS              Adj. R-squared:     0.827
#  Dependent Variable: AMZN             AIC:                20786.8935
#  Date:               2020-01-14 20:49 BIC:                20797.5333
#  No. Observations:   1510             Log-Likelihood:     -10391.
#  Df Model:           1                F-statistic:        7196.
#  Df Residuals:       1508             Prob (F-statistic): 0.00
#  R-squared:          0.827            Scale:              55656.
#  --------------------------------------------------------------------
#             Coef.    Std.Err.     t      P>|t|     [0.025     0.975]
#  --------------------------------------------------------------------
#  const    -526.0965   18.8141  -27.9629  0.0000  -563.0011  -489.1920
#  FB         11.5599    0.1363   84.8264  0.0000    11.2926    11.8272
#  -------------------------------------------------------------------
#  Omnibus:              40.651        Durbin-Watson:           0.011
#  Prob(Omnibus):        0.000         Jarque-Bera (JB):        43.486
#  Skew:                 0.394         Prob(JB):                0.000
#  Kurtosis:             3.262         Condition No.:           428
#  ===================================================================
#
#  """,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1c21296668>,
#  LinregressResult(slope=11.559915734959237, intercept=-526.0965372891827, rvalue=0.9092506198992242, pvalue=0.0, stderr=0.13627735489714812))

# %%
fig, axes = plt.subplots(2,2, figsize = (16,10))
