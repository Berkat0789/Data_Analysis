# %% [markdown]
# ### The python jupyter notebook is to compare securties behavor and generate correlation analysis between them. the list of methods to do this is as follows

# %%
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sidusPkg import fetch_Stock_Data

# %%
Sidus = fetch_Stock_Data.Firm(["TSLA", "AMZN"], start= '2011-1-1', end = "2018-1-1", data_type= "Open")

# %%
Sidus.fetch_Data()
# Out:
# [             TSLA        AMZN
#  Date
#  2011-01-03  26.84  181.369995
#  2011-01-04  26.66  186.149994
#  2011-01-05  26.48  184.100006
#  2011-01-06  26.83  186.500000
#  2011-01-07  28.00  187.880005,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1c21fe6bd0>]

# %%
Sidus.plot_graphs()
# Out:
# here is the length 2
# here is the length 2

# %%
Sidus.dailyChanges("box")
# Out:
# [                TSLA      AMZN
#  Date
#  2017-12-26 -0.024324  0.007190
#  2017-12-27 -0.017807  0.004674
#  2017-12-28  0.011937  0.003248
#  2017-12-29 -0.012716 -0.014021
#  2018-01-02  0.029484  0.016708,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1c21f7b1d0>]

# %%
Sidus.dailyReturns()
# Out:
# [                 TSLA      AMZN
#  Date
#  2017-12-26  11.919234  6.387797
#  2017-12-27  11.706987  6.417653
#  2017-12-28  11.846731  6.438497
#  2017-12-29  11.696093  6.348225
#  2018-01-02  12.040946  6.454294,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1c22036c10>]

# %%
Sidus.compare2("AMZN","TSLA")
# Out:
# /Users/admin/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# (<class 'statsmodels.iolib.summary2.Summary'>
#  """
#                    Results: Ordinary least squares
#  ===================================================================
#  Model:              OLS              Adj. R-squared:     0.647
#  Dependent Variable: TSLA             AIC:                19608.9467
#  Date:               2020-01-16 15:41 BIC:                19619.8951
#  No. Observations:   1762             Log-Likelihood:     -9802.5
#  Df Model:           1                F-statistic:        3226.
#  Df Residuals:       1760             Prob (F-statistic): 0.00
#  R-squared:          0.647            Scale:              3983.0
#  ---------------------------------------------------------------------
#               Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
#  ---------------------------------------------------------------------
#  const       20.1905     2.9294    6.8923   0.0000   14.4450   25.9360
#  AMZN         0.3127     0.0055   56.7965   0.0000    0.3019    0.3235
#  -------------------------------------------------------------------
#  Omnibus:              336.273       Durbin-Watson:          0.006
#  Prob(Omnibus):        0.000         Jarque-Bera (JB):       174.733
#  Skew:                 0.626         Prob(JB):               0.000
#  Kurtosis:             2.097         Condition No.:          1037
#  ===================================================================
#  * The condition number is large (1e+03). This might indicate
#  strong multicollinearity or other numerical problems.
#  """,
#  LinregressResult(slope=0.3127423303954078, intercept=20.19045613737967, rvalue=0.8043635989903348, pvalue=0.0, stderr=0.005506362341862639))

# %%
Sidus.portfolio_return([0.25, 0.75])
# Out:
# TSLA    0.470399
# AMZN    0.312048
# dtype: float64
# "The return for the portfolio containing ['TSLA', 'AMZN'] is 35.164 % for the period of 2011-1-1 to 2018-1-1"

# %%
Sidus.check_Portfolio_Volitility([0.35, 0.65])
# Out:
# "The Volitility of the portfolio containing ['TSLA', 'AMZN'] is 29.759999999999998 % for the period of 2011-1-1 to 2018-1-1"
