# %% [markdown]
# ### The python jupyter notebook is to compare securties behavor and generate correlation analysis between them. the list of methods to do this is as follows

# %%
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sidusPkg import fetch_Stock_Data

# %%
Sidus = fetch_Stock_Data.Firm(["FB", "AMZN", "TSLA", "AAPL"], start= '2014-1-1')

# %%
Sidus.plot_4_plots()

# %%
Sidus.fetch_Data()
# Out:
# [                   FB        AMZN        TSLA       AAPL
#  Date
#  2014-01-02  54.709999  397.970001  150.100006  71.107201
#  2014-01-03  54.560001  396.440002  149.559998  69.545288
#  2014-01-06  57.200001  393.630005  147.000000  69.924515
#  2014-01-07  57.919998  398.029999  149.360001  69.424438
#  2014-01-08  58.230000  401.920013  151.279999  69.864105,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1c1e77e0f0>]

# %%
Sidus.dailyChanges("box")
# Out:
# [                  FB      AMZN      TSLA      AAPL
#  Date
#  2019-12-24 -0.005141 -0.002114  0.014384  0.000951
#  2019-12-26  0.013017  0.044467  0.013380  0.019840
#  2019-12-27  0.001492  0.000551 -0.001299 -0.000379
#  2019-12-30 -0.017732 -0.012253 -0.036433  0.005935
#  2019-12-31  0.004109  0.000514  0.008753  0.007307,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1c20d645c0>]

# %%
Sidus.dailyReturns()
# Out:
# [                  FB      AMZN      TSLA      AAPL
#  Date
#  2019-12-24  3.749223  4.495841  2.833111  3.997767
#  2019-12-26  3.798026  4.695756  2.871019  4.077084
#  2019-12-27  3.803692  4.698344  2.867288  4.075536
#  2019-12-30  3.736246  4.640777  2.762825  4.099725
#  2019-12-31  3.751599  4.643164  2.787008  4.129680,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1c20bb1518>]

# %%
Sidus.compare2("AAPL","TSLA")
# Out:
# (<class 'statsmodels.iolib.summary2.Summary'>
#  """
#                    Results: Ordinary least squares
#  ===================================================================
#  Model:              OLS              Adj. R-squared:     0.379
#  Dependent Variable: TSLA             AIC:                15686.8892
#  Date:               2020-01-14 21:22 BIC:                15697.5289
#  No. Observations:   1510             Log-Likelihood:     -7841.4
#  Df Model:           1                F-statistic:        920.5
#  Df Residuals:       1508             Prob (F-statistic): 3.13e-158
#  R-squared:          0.379            Scale:              1899.7
#  ---------------------------------------------------------------------
#            Coef.     Std.Err.      t      P>|t|     [0.025     0.975]
#  ---------------------------------------------------------------------
#  const    164.7846     3.3735   48.8473   0.0000   158.1674   171.4018
#  AAPL       0.6967     0.0230   30.3394   0.0000     0.6517     0.7418
#  -------------------------------------------------------------------
#  Omnibus:               10.151        Durbin-Watson:           0.028
#  Prob(Omnibus):         0.006         Jarque-Bera (JB):        9.133
#  Skew:                  0.139         Prob(JB):                0.010
#  Kurtosis:              2.740         Condition No.:           442
#  ===================================================================
#
#  """,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1c20ddbb70>,
#  LinregressResult(slope=0.6967417909078862, intercept=164.78459001575325, rvalue=0.6156588613883519, pvalue=3.1262808720950367e-158, stderr=0.022964887624746043))
