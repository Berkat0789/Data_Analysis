# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ###  Data Source
# https://www.gunviolencearchive.org/export-finished?filename=public%3A//export-6f93059b-fcb3-4777-86e5-bb5fc7252854.csv&uuid=387f857c-72b0-41fe-9b3c-7f2a37cda71c&return_href=reports/mass-shootings/2014

# %%
mass_shootings_2014 = pd.read_csv("GVAMassShooting2014.csv", index_col="Incident Date", parse_dates=True)
mass_shootings_2015 = pd.read_csv("GVAMassShooting2015.csv", index_col="Incident Date", parse_dates=True)
mass_shootings_2017 = pd.read_csv("GVAMassShooting2017.csv", index_col="Incident Date", parse_dates=True)
mass_shootings_2018 = pd.read_csv("GVAMassShooting2018.csv", index_col="Incident Date", parse_dates=True)
mass_shootings_2019 = pd.read_csv("GVAMassShootings2019.csv", index_col="Incident Date", parse_dates=True)

# %%
mass_shootings_2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 269 entries, 2014-12-29 to 2014-01-01
# Data columns (total 7 columns):
# Incident ID       269 non-null int64
# State             269 non-null object
# City Or County    269 non-null object
# Address           268 non-null object
# # Killed          269 non-null int64
# # Injured         269 non-null int64
# Operations        0 non-null float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 16.8+ KB

# %%
mass_shootings_2014["# Killed"].sort_values(ascending = False ).plot(figsize = (16,6))

# %%
mass_shootings_2018["# Killed"].sort_values(ascending = False).plot(figsize = (16,6))

# %%
mass_shootings_2015["# Killed"].sort_values(ascending = False).plot(figsize = (16,6))

# %%
mass_shootings_2019["# Killed"].sort_values(ascending = False).plot(figsize = (16,6))

# %%
mass_shootings_2017["# Killed"].sort_values(ascending = False).plot(figsize = (16,6))
