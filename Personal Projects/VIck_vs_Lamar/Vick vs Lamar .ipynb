# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
vick_passing = pd.read_excel("vick.xlsx", sheet_name= "passing")

# %%
vick_rushing = pd.read_excel("vick.xlsx",sheet_name="rushing")

# %%
vick_rushing
# Out:
#     Year  Age   Tm Pos  No.   G  GS  Rush   Yds  TD ...   Lng.1  R/G  Y/G.1  \
# 0   2001   21  ATL  qb    7   8   2    31   289   1 ...     NaN  NaN    NaN
# 1   2002   22  ATL  QB    7  15  15   113   777   8 ...    16.0  0.0    1.1
# 2   2003   23  ATL  qb    7   5   4    40   255   1 ...     NaN  NaN    NaN
# 3   2004   24  ATL  QB    7  15  15   120   902   3 ...     NaN  NaN    NaN
# 4   2005   25  ATL  QB    7  15  15   102   597   6 ...   -14.0  0.1   -0.9
# 5   2006   26  ATL  QB    7  16  16   123  1039   2 ...     1.0  0.1    0.1
# 6   2009   29  PHI  rb    7  12   1    24    95   2 ...     NaN  NaN    NaN
# 7   2010   30  PHI  QB    7  12  12   100   676   9 ...     NaN  NaN    NaN
# 8   2011   31  PHI  QB    7  13  13    76   589   1 ...     NaN  NaN    NaN
# 9   2012   32  PHI  QB    7  10  10    62   332   1 ...     NaN  NaN    NaN
# 10  2013   33  PHI  qb    7   7   6    36   306   2 ...    -2.0  0.0   -0.3
# ...

# %%
vick_passing
# Out:
#       Year     Age                                                 Tm  \
# 0     2001      21                                                ATL
# 1    2002*      22                                                ATL
# 2     2003      23                                                ATL
# 3    2004*      24                                                ATL
# 4    2005*      25                                                ATL
# 5     2006      26                                                ATL
# 6     2007     NaN  Missed season - Violation of league personal c...
# 7     2008     NaN  Missed season - Violation of league personal c...
# 8     2009      29                                                PHI
# 9    2010*      30                                                PHI
# 10    2011      31                                                PHI
# 11    2012      32                                                PHI
# ...

# %%
lamar_passing = pd.read_excel("lamar.xlsx", sheet_name="passing")

# %%
lamar_passing
# Out:
#    Year  Age   Tm Pos  No.   G  GS                QBrec  Cmp  Att ...   Rate  \
# 0  2018   21  BAL  qb    8  16   7  2000-06-01 00:00:00   99  170 ...   84.5
# 1  2019   22  BAL  QB    8  15  15               13-2-0  265  401 ...  113.3
#
#     QBR  Sk  Yds.1  NY/A  ANY/A  Sk%  4QC  GWD  AV
# 0  46.3  16     71  6.08   5.99  8.6    0    1   8
# 1  81.1  23    106  7.13   8.19  5.4    1    2   0
#
# [2 rows x 32 columns]

# %%
lamar_rushing = pd.read_excel("lamar.xlsx", sheet_name="rushing")

# %%
lamar_rushing
# Out:
#    Year  Age   Tm Pos  No.   G  GS  Rush   Yds  TD ...   Lng.1  R/G  Y/G.1  \
# 0  2018   21  BAL  qb    8  16   7   147   695   5 ...       0    0      0
# 1  2019   22  BAL  QB    8  15  15   176  1206   7 ...       0    0      0
#
#    Ctch%  Y/Tgt  Touch  Y/Tch  YScm  RRTD  Fmb
# 0      0      0    147    4.7   695     5   12
# 1      0      0    176    6.9  1206     7    9
#
# [2 rows x 31 columns]

# %%
lamar_Data = lamar_passing[["Year","Cmp", "Att", "Cmp%", "Yds", "TD", "Int"]]

# %%
lamar_Data
# Out:
#    Year  Cmp  Att  Cmp%   Yds  TD  Int  rush_amt  rush_yrd  rush_tds  rush_Fmb
# 0  2018   99  170  58.2  1201   6    3       147       695         5        12
# 1  2019  265  401  66.1  3127  36    6       176      1206         7         9

# %%
vick_rushing.loc[0:1]
# Out:
#    Year  Age   Tm Pos  No.   G  GS  Rush  Yds  TD ...   Lng.1  R/G  Y/G.1  \
# 0  2001   21  ATL  qb    7   8   2    31  289   1 ...     NaN  NaN    NaN
# 1  2002   22  ATL  QB    7  15  15   113  777   8 ...    16.0  0.0    1.1
#
#    Ctch%  Y/Tgt  Touch  Y/Tch  YScm  RRTD  Fmb
# 0    NaN    NaN     31    9.3   289     1    6
# 1    0.0   16.0    113    7.0   793     8    9
#
# [2 rows x 31 columns]

# %%
vick_Data = vick_passing[["Year","Cmp", "GS","Att", "Cmp%", "Yds", "TD", "Int"]].loc[0:1]

# %%
vick_Data
# Out:
#     Year  Cmp  GS  Att  Cmp%   Yds  TD Int  rsh_att  rsh_yrd  rsh_tds  rsh_Fmb
# 0   2001   50   2  113  44.2   785   2   3       31      289        1        6
# 1  2002*  231  15  421  54.9  2936  16   8      113      777        8        9

# %%
lamar_Data
# Out:
#    Year  Cmp  Att  Cmp%   Yds  TD  Int  rush_amt  rush_yrd  rush_tds  rush_Fmb
# 0  2018   99  170  58.2  1201   6    3       147       695         5        12
# 1  2019  265  401  66.1  3127  36    6       176      1206         7         9

# %%
date_time = [datetime(2001,1,12,12), datetime(2002,1,12,12), datetime(2018,1,12,12), datetime(2019,1,12,12)]

# %%
date_time_index = pd.DatetimeIndex(date_time)

# %%
date_time_index
# Out:
# DatetimeIndex(['2001-01-12 12:00:00', '2002-01-12 12:00:00',
#                '2018-01-12 12:00:00', '2019-01-12 12:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
lamar_Data.set_index(date_time_index[2:].year, inplace = True)

# %%
lamar_Data
# Out:
#       Cmp  Att  Cmp%   Yds  TD  Int  rush_amt  rush_yrd  rush_tds  rush_Fmb
# 2018   99  170  58.2  1201   6    3       147       695         5        12
# 2019  265  401  66.1  3127  36    6       176      1206         7         9

# %%
vick_Data.set_index(date_time_index[0:2].year)
# Out:
#       Cmp  GS  Att  Cmp%   Yds  TD Int  rsh_att  rsh_yrd  rsh_tds  rsh_Fmb
# 2001   50   2  113  44.2   785   2   3       31      289        1        6
# 2002  231  15  421  54.9  2936  16   8      113      777        8        9

# %%
plt.figure(figsize=(15,5))
plt.scatter(date_time_index[2:].year,lamar_Data["Yds"])
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.scatter(date_time_index[0:2].year,vick_Data["Yds"])
plt.show()
