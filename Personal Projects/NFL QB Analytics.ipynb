# %%
import pandas as pd
from pandas_datareader import data as web
import numpy as np
import matplotlib.pyplot as plt

# %%
qb_data = pd.read_csv("QBStats_all.csv", index_col="year", parse_dates=True)

# %%
qb_data
# Out:
#                                        qb  att  cmp    yds  ypa  td int   lg  \
# year
# 1996-01-01       Boomer EsiasonB. Esiason   38   25  237.0  6.2   0   0   20
# 1996-01-01        Jim HarbaughJ. Harbaugh   25   16  196.0  7.8   2   1  35t
# 1996-01-01           Paul JustinP. Justin    8    5   53.0  6.6   0   0   30
# 1996-01-01           Jeff GeorgeJ. George   35   16  215.0  6.1   0   0   55
# 1996-01-01        Kerry CollinsK. Collins   31   17  198.0  6.4   2   0   30
# ...                                   ...  ...  ...    ...  ...  ..  ..  ...
# 2016-01-01             Alex SmithA. Smith   28   21  264.0  9.4   2   1   42
# 2016-01-01         Philip RiversP. Rivers   38   22  269.0  7.1   2   2   23
# 2016-01-01        Russell WilsonR. Wilson   32   19  258.0  8.1   1   0   42
# 2016-01-01        Trevone BoykinT. Boykin    6    4   42.0  7.0   0   0   19
# 2016-01-01  Colin KaepernickC. Kaepernick   22   17  215.0  9.8   1   0   29
#
# ...
